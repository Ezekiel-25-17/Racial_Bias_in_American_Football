# %%
from sklearn.metrics import classification_report, f1_score, accuracy_score, confusion_matrix
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import roc_curve, auc, roc_auc_score
from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier
from sklearn.dummy import DummyClassifier
from gensim.models import Word2Vec
import matplotlib.pyplot as plt
import statsmodels.api as sm
import seaborn as sns
import pandas as pd
import numpy as np
import gensim
import pickle
import nltk
import os

# %%
# Load our dataset
path = 'dataset-football_commentary'
filename = 'qb_mentions_12.csv'

df = pd.read_csv(os.path.join(path, filename))

# %%
df.head(3)
# Out:
#          Player  Year   Race  \
# 0  Matt Leinart  2006  White
# 1  Matt Leinart  2006  White
# 2  Matt Leinart  2006  White
#
#                                              Mention  \
# 0  ['seen', 'a', 'lot,', 'and', 'weve', 'seen', '...
# 1  ['lot', 'that', 's', '<player>', '&gt;&gt;', '...
# 2  ['all', 'you', 'need', 'to', 'do', 'is', 'look...
#
#                           Mention_Cleaned
# 0            see lot see win lot mike top
# 1  lot s mike top need look simple number
# 2     look simple number life starter man

# %%
y = df['Race'].value_counts() / len(df)

sns.set(font_scale=1.5)
sns.barplot(x=y.index, y=y).set_title('Commentary: Class Balance')
plt.show()

# %%
# Training Data
X_train = df['Mention_Cleaned']
y_train = np.asarray(df['Race'].map({'White' : 0, 'Non-White' : 1}))

vectorizer = TfidfVectorizer(use_idf=True)
X_train = vectorizer.fit_transform(X_train)

print(X_train.shape)
print(y_train.shape)
# Out:
# (36571, 14860)
# (36571,)

# %% [markdown]
# ## Logistic Regression

# %%
# Logistic Regression
grid = {'C' : np.arange(1, 17, 3), 
        'penalty' : ['l1', 'l2'],
        'solver' : ['liblinear', 'saga'],
        'max_iter' : [100000]} 

classifier = LogisticRegression()
classifier_cv = GridSearchCV(classifier, grid, cv=10, scoring='f1_micro')
classifier_cv.fit(X_train,y_train)

print('Tuned Hyperparameters: ',  classifier_cv.best_params_)
print('F1 :', classifier_cv.best_score_)
# Out:
# Tuned Hyperparameters:  {'C': 1, 'max_iter': 100000, 'penalty': 'l1', 'solver': 'liblinear'}
# F1 : 0.6417381347186047

# %%
classifier = LogisticRegression(C=1, max_iter=100000, penalty='l1', solver='liblinear')
classifier.fit(X_train, y_train)
# Out:
# LogisticRegression(C=1, max_iter=100000, penalty='l1', solver='liblinear')

# %%
# Save our dataframe
checkpoint = '__checkpoints'
filename = 'commentary-coeff_logreg.csv'

important_tokens = pd.DataFrame(data=classifier.coef_[0], index=vectorizer.get_feature_names_out(), columns=['Coefficient']).reset_index().rename(columns={'index':'Word'}).reset_index().rename(columns={'index':'Index'})
important_tokens = important_tokens.sort_values('Coefficient', ascending=False).reset_index(drop=True)
important_tokens.to_csv(os.path.join(checkpoint, filename), index=False)

# %%
# Load our dataframe
checkpoint = '__checkpoints'
filename = 'commentary-coeff_logreg.csv'

important_tokens = pd.read_csv(os.path.join(checkpoint, filename))
important_tokens.head(5)
# Out:
#    Index        Word  Coefficient
# 0   7972  louisville    10.829044
# 1  14136       verne     9.746412
# 2   7086        josh     7.887956
# 3   5445      gerard     7.615849
# 4  12941    syracuse     6.086978

# %%
matrix = X_train.todense()

for index, row in important_tokens.iterrows():
    if index == 0:
        train_df = pd.DataFrame(X_train.todense()[:, row['Index']], columns=[important_tokens[important_tokens['Index'] == row['Index']]['Word'].reset_index(drop=True)[0]])
    else:
        train_df = pd.concat([train_df, pd.DataFrame(X_train.todense()[:, row['Index']], columns=[important_tokens[important_tokens['Index'] == row['Index']]['Word'].reset_index(drop=True)[0]])], axis=1)
        
train_df.shape
# Out:
# (36571, 440)

# %%
model = sm.Logit(y_train, train_df).fit(maxiter=100000, method='bfgs')
# Out:
# Optimization terminated successfully.
#          Current function value: 0.588598
#          Iterations: 342
#          Function evaluations: 347
#          Gradient evaluations: 347

# %%
print(model.summary())
# Out:
#                            Logit Regression Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                36571
# Model:                          Logit   Df Residuals:                    36131
# Method:                           MLE   Df Model:                          439
# Date:                Sat, 04 Feb 2023   Pseudo R-squ.:                 0.09906
# Time:                        19:50:33   Log-Likelihood:                -21526.
# converged:                       True   LL-Null:                       -23892.
# Covariance Type:            nonrobust   LLR p-value:                     0.000
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# louisville        11.0198      1.345      8.191      0.000       8.383      13.657
# verne             18.8164      7.591      2.479      0.013       3.939      33.694
# josh               7.7740      0.739     10.515      0.000       6.325       9.223
# gerard            11.2350      3.342      3.362      0.001       4.685      17.785
# syracuse          11.9154      3.889      3.064      0.002       4.294      19.537
# jc                 9.9661      2.630      3.790      0.000       4.812      15.120
# eliot             13.1813      8.284      1.591      0.112      -3.054      29.417
# shawn              5.3585      0.755      7.101      0.000       3.880       6.837
# kapernick         13.5279      7.756      1.744      0.081      -1.673      28.729
# gulman            12.3209      7.307      1.686      0.092      -2.000      26.642
# charissa          16.9314      6.209      2.727      0.006       4.762      29.101
# kelsey             5.6371      1.433      3.934      0.000       2.829       8.445
# gino               5.2232      1.164      4.487      0.000       2.942       7.505
# renfro            12.1254      7.346      1.651      0.099      -2.273      26.524
# clemson            4.7410      0.771      6.148      0.000       3.230       6.252
# kentucky           4.9830      0.991      5.027      0.000       3.040       6.926
# rutger             5.3973      1.392      3.877      0.000       2.669       8.126
# holme              5.2567      1.399      3.757      0.000       2.514       7.999
# marcus             4.1707      1.002      4.161      0.000       2.206       6.135
# wilson             4.2288      0.853      4.958      0.000       2.557       5.900
# cam                4.4083      1.098      4.013      0.000       2.255       6.561
# kane              10.5444      7.155      1.474      0.141      -3.479      24.568
# keeper             5.0876      1.114      4.567      0.000       2.904       7.271
# seminole           4.4865      1.410      3.183      0.001       1.724       7.249
# panther            3.3015      0.734      4.496      0.000       1.862       4.741
# russell            3.2012      0.889      3.601      0.000       1.459       4.944
# huntley            6.7867      3.015      2.251      0.024       0.877      12.696
# radcliffe         10.7899      7.416      1.455      0.146      -3.746      25.325
# zeke               6.5021      1.994      3.261      0.001       2.595      10.410
# seahawk            3.7802      0.975      3.878      0.000       1.870       5.691
# shaun              4.2807      1.283      3.336      0.001       1.766       6.796
# elliot             8.6345      3.325      2.597      0.009       2.117      15.152
# thom               3.5687      0.888      4.019      0.000       1.828       5.309
# volunteer         12.2448      6.920      1.770      0.077      -1.318      25.808
# oregon             3.2803      0.725      4.527      0.000       1.860       4.701
# garage            10.1225      7.468      1.355      0.175      -4.515      24.760
# wolfpack           6.7093      2.669      2.514      0.012       1.478      11.940
# shermer           10.1677      6.456      1.575      0.115      -2.485      22.821
# pat                2.6186      0.761      3.439      0.001       1.126       4.111
# baron              9.9985      7.065      1.415      0.157      -3.850      23.847
# dec                9.5889      7.718      1.242      0.214      -5.538      24.716
# humphrey           5.4743      2.592      2.112      0.035       0.393      10.555
# carolina           2.4213      0.558      4.341      0.000       1.328       3.514
# ferret             9.7017      7.213      1.345      0.179      -4.436      23.840
# seattle            2.2862      0.469      4.877      0.000       1.367       3.205
# schottenheimer     5.5608      2.512      2.214      0.027       0.637      10.484
# wisconsin          2.7390      0.739      3.706      0.000       1.291       4.187
# bevell            10.0965      7.072      1.428      0.153      -3.765      23.958
# ginn               3.7521      1.601      2.343      0.019       0.613       6.891
# perset             9.3683      6.760      1.386      0.166      -3.880      22.617
# jon                2.7535      0.762      3.611      0.000       1.259       4.248
# petrino            4.5882      1.848      2.482      0.013       0.965       8.211
# mountaineer       11.7376      5.808      2.021      0.043       0.353      23.122
# clay               8.7994      7.064      1.246      0.213      -5.045      22.644
# mackinnon          9.2137      6.843      1.346      0.178      -4.199      22.626
# threat             2.4905      0.755      3.299      0.001       1.011       3.970
# pete               1.4771      1.179      1.253      0.210      -0.834       3.788
# schneider          7.0600      2.779      2.540      0.011       1.613      12.507
# damn               3.4931      1.654      2.112      0.035       0.251       6.735
# gallop             2.8779      1.185      2.428      0.015       0.555       5.201
# meyer              2.2206      1.077      2.062      0.039       0.110       4.331
# tabas              8.9524      6.494      1.379      0.168      -3.776      21.681
# iglesia            9.1614      7.171      1.278      0.201      -4.893      23.216
# duke               2.4573      1.088      2.258      0.024       0.325       4.590
# development        3.0168      1.421      2.122      0.034       0.231       5.803
# jimbo              4.5800      1.861      2.461      0.014       0.933       8.228
# habit              3.8870      1.741      2.232      0.026       0.474       7.300
# overwhelm          7.0436      3.011      2.339      0.019       1.141      12.946
# contain            1.7982      0.721      2.492      0.013       0.384       3.212
# stable             8.2280      6.721      1.224      0.221      -4.944      21.400
# blocker            1.7945      0.768      2.338      0.019       0.290       3.299
# badger             2.9464      1.356      2.173      0.030       0.289       5.604
# mahone             5.2741      2.769      1.904      0.057      -0.154      10.702
# quin               5.2597      2.898      1.815      0.070      -0.420      10.940
# brad               1.7242      0.581      2.968      0.003       0.586       2.863
# buckeye            1.4084      0.789      1.785      0.074      -0.138       2.955
# joe                1.3681      0.357      3.829      0.000       0.668       2.069
# roman             10.0232      6.438      1.557      0.119      -2.595      22.641
# electric           5.0769      2.759      1.840      0.066      -0.330      10.484
# 49ers              3.9744      1.836      2.165      0.030       0.376       7.573
# obrien             2.6882      0.910      2.954      0.003       0.905       4.472
# cutter             3.1114      1.504      2.069      0.039       0.164       6.058
# pit                2.6040      1.247      2.088      0.037       0.160       5.048
# swear              6.1869      2.531      2.445      0.014       1.227      11.147
# account            1.9194      0.884      2.172      0.030       0.187       3.652
# percent            1.4898      0.718      2.076      0.038       0.083       2.896
# secure             2.2913      0.930      2.464      0.014       0.468       4.114
# scott              1.6664      0.789      2.112      0.035       0.120       3.213
# beg                3.1823      1.416      2.247      0.025       0.407       5.958
# belt               3.1696      1.480      2.142      0.032       0.269       6.070
# herman             9.4638      6.501      1.456      0.145      -3.278      22.206
# acc                2.9120      1.457      1.998      0.046       0.056       5.768
# hickety            8.0110      6.558      1.222      0.222      -4.843      20.865
# showtime           4.6039      2.327      1.978      0.048       0.043       9.165
# peel               2.7424      1.756      1.562      0.118      -0.699       6.184
# webber             9.1830      6.557      1.400      0.161      -3.669      22.035
# troy               1.1268      0.391      2.881      0.004       0.360       1.893
# partner            2.5242      1.296      1.948      0.051      -0.016       5.064
# grisham            5.7290      2.921      1.961      0.050       0.003      11.454
# pursuit            1.8251      1.012      1.804      0.071      -0.158       3.808
# twoman             9.5239      3.419      2.785      0.005       2.822      16.226
# parent             1.9203      0.982      1.956      0.050      -0.004       3.845
# jajuan             6.2706      3.052      2.054      0.040       0.288      12.253
# billy              4.2396      2.223      1.907      0.056      -0.117       8.596
# date               1.4652      0.981      1.494      0.135      -0.457       3.387
# nightmare          2.2448      1.252      1.793      0.073      -0.209       4.699
# drag               1.6331      0.901      1.813      0.070      -0.132       3.398
# heisman            0.7840      0.713      1.099      0.272      -0.614       2.182
# katie              3.3326      1.930      1.727      0.084      -0.449       7.114
# lee                1.5235      0.954      1.597      0.110      -0.346       3.393
# leadership         1.5457      0.856      1.806      0.071      -0.131       3.223
# dive               1.5262      0.829      1.842      0.066      -0.098       3.151
# cooper             1.2685      0.882      1.438      0.151      -0.461       2.998
# iglesias           6.3249      3.485      1.815      0.070      -0.506      13.156
# explosive          1.9800      0.868      2.280      0.023       0.278       3.682
# worried            1.8073      1.148      1.574      0.115      -0.443       4.057
# gano               8.3313      7.267      1.146      0.252      -5.911      22.574
# russel             8.8876      6.403      1.388      0.165      -3.662      21.437
# lamar              4.9900      2.045      2.440      0.015       0.982       8.998
# utah               2.5272      1.208      2.092      0.036       0.159       4.895
# tech               0.8628      0.541      1.594      0.111      -0.198       1.924
# maintain           1.8840      1.116      1.688      0.091      -0.303       4.071
# crack              2.3780      1.310      1.815      0.070      -0.190       4.946
# jp                 6.1043      2.505      2.437      0.015       1.194      11.014
# bostick            3.2928      2.068      1.593      0.111      -0.759       7.345
# turner             2.1258      1.302      1.633      0.102      -0.425       4.677
# trophy             2.0435      0.914      2.235      0.025       0.251       3.836
# gabbard            8.9049      6.283      1.417      0.156      -3.410      21.219
# elusive            1.6015      1.100      1.455      0.146      -0.555       3.758
# gary               1.3455      0.831      1.618      0.106      -0.284       2.975
# capable            1.1230      0.754      1.490      0.136      -0.354       2.600
# kelly              0.9794      0.731      1.339      0.181      -0.454       2.413
# kaepernick         2.8578      1.533      1.864      0.062      -0.147       5.863
# stephen            4.0945      1.915      2.139      0.032       0.342       7.847
# lock               1.2661      0.721      1.756      0.079      -0.147       2.679
# buccaneer          1.0079      0.866      1.163      0.245      -0.690       2.706
# passing            2.3502      1.164      2.018      0.044       0.068       4.632
# cold               1.8605      1.108      1.680      0.093      -0.311       4.032
# playbook           1.8352      1.151      1.594      0.111      -0.421       4.091
# intention          3.7175      2.253      1.650      0.099      -0.698       8.133
# nearside           1.6392      1.011      1.621      0.105      -0.342       3.621
# total              0.9284      0.553      1.680      0.093      -0.155       2.011
# evan               1.4413      1.061      1.358      0.174      -0.639       3.521
# curse              2.0611      1.404      1.468      0.142      -0.691       4.813
# hammer             1.6694      1.234      1.352      0.176      -0.750       4.089
# buffalo            0.7071      0.506      1.396      0.163      -0.285       1.699
# rivera             2.7788      1.787      1.555      0.120      -0.724       6.282
# maneuver           8.4383      6.672      1.265      0.206      -4.639      21.516
# gillis             9.3809      6.072      1.545      0.122      -2.520      21.281
# comparison         1.0225      0.865      1.183      0.237      -0.672       2.717
# florida            0.7028      0.508      1.385      0.166      -0.292       1.698
# stephane           6.9725      3.124      2.232      0.026       0.849      13.096
# aspect             1.9334      1.312      1.474      0.140      -0.637       4.504
# auburn             2.0631      1.161      1.778      0.075      -0.212       4.338
# alamo              7.5697      6.277      1.206      0.228      -4.734      19.873
# obviously          0.2956      0.485      0.609      0.542      -0.655       1.246
# tampa              0.4438      0.750      0.591      0.554      -1.027       1.915
# de                 3.7608      2.102      1.789      0.074      -0.359       7.881
# fat                2.7556      1.645      1.675      0.094      -0.469       5.980
# sling              1.7811      0.860      2.072      0.038       0.096       3.466
# athlete            0.7971      0.743      1.073      0.283      -0.659       2.253
# arizona            0.5937      0.494      1.202      0.229      -0.374       1.562
# ground             0.3073      0.363      0.846      0.398      -0.405       1.019
# gap                1.4095      0.778      1.812      0.070      -0.115       2.934
# anthony            2.8984      1.232      2.354      0.019       0.485       5.312
# skill              1.0894      0.843      1.293      0.196      -0.562       2.741
# baldwin            4.2497      2.515      1.690      0.091      -0.679       9.178
# forest             2.1170      1.125      1.882      0.060      -0.088       4.321
# elliott            4.1849      2.260      1.852      0.064      -0.244       8.614
# kingsbury          2.5487      1.578      1.615      0.106      -0.544       5.641
# news               0.3902      0.759      0.514      0.607      -1.098       1.878
# draw               0.5114      0.593      0.863      0.388      -0.650       1.673
# martin             2.1349      0.998      2.138      0.032       0.178       4.092
# grand              6.5859      3.189      2.065      0.039       0.336      12.835
# typical            3.6503      2.021      1.806      0.071      -0.311       7.612
# wet                2.1792      1.407      1.548      0.122      -0.579       4.938
# slip               0.5702      0.660      0.864      0.388      -0.723       1.864
# recruit            1.3657      1.134      1.204      0.229      -0.857       3.589
# option             0.7179      0.427      1.682      0.092      -0.118       1.554
# language           3.8040      1.947      1.954      0.051      -0.012       7.620
# zach               2.1769      1.285      1.694      0.090      -0.342       4.695
# indicator          6.9998      4.762      1.470      0.142      -2.333      16.333
# onside             1.3344      1.164      1.147      0.252      -0.946       3.615
# newage             7.9282      6.989      1.134      0.257      -5.770      21.626
# escape             0.4518      0.498      0.908      0.364      -0.523       1.427
# engage             2.2021      1.526      1.443      0.149      -0.788       5.192
# duck               0.6708      0.680      0.987      0.324      -0.662       2.003
# leftwich           5.7016      3.012      1.893      0.058      -0.201      11.604
# death              1.2937      1.065      1.215      0.224      -0.794       3.381
# grind              1.9297      1.335      1.445      0.148      -0.687       4.547
# aware              1.4974      1.087      1.377      0.168      -0.633       3.628
# godwin             7.3219      6.293      1.163      0.245      -5.012      19.656
# chase              0.3204      0.482      0.665      0.506      -0.624       1.265
# thirddown          4.0606      1.959      2.073      0.038       0.222       7.899
# manage             1.2115      0.953      1.271      0.204      -0.657       3.080
# upfield            2.0157      1.366      1.476      0.140      -0.662       4.693
# country            0.6805      0.647      1.053      0.293      -0.587       1.948
# orlando            2.0844      1.400      1.489      0.136      -0.659       4.828
# ability            0.3436      0.408      0.842      0.400      -0.456       1.143
# sale               1.7430      1.427      1.221      0.222      -1.054       4.540
# mariota            5.4760      2.992      1.830      0.067      -0.389      11.341
# tiger              0.9063      0.659      1.375      0.169      -0.385       2.198
# offer              1.6740      1.104      1.517      0.129      -0.489       3.837
# simon              5.7177      2.844      2.010      0.044       0.143      11.293
# run               -0.6074      0.188     -3.237      0.001      -0.975      -0.240
# perhaps            0.4869      0.871      0.559      0.576      -1.221       2.195
# 75yard             7.5663      6.359      1.190      0.234      -4.896      20.029
# realize            1.1365      0.717      1.585      0.113      -0.269       2.542
# block             -0.0010      0.353     -0.003      0.998      -0.693       0.691
# card               1.1092      0.954      1.163      0.245      -0.760       2.978
# quiet              0.3914      0.844      0.464      0.643      -1.263       2.045
# image              2.8301      1.667      1.698      0.090      -0.437       6.097
# nebraska           3.2462      1.594      2.036      0.042       0.121       6.371
# berry              1.4082      1.336      1.054      0.292      -1.210       4.026
# large              1.7705      1.302      1.360      0.174      -0.782       4.323
# jd                 2.9033      1.408      2.061      0.039       0.143       5.664
# direction          0.5592      0.634      0.883      0.377      -0.682       1.801
# hesitation         2.1562      1.427      1.511      0.131      -0.641       4.953
# part              -0.1210      0.415     -0.292      0.771      -0.934       0.692
# core               1.8238      1.228      1.485      0.138      -0.583       4.231
# state              0.0171      0.342      0.050      0.960      -0.654       0.688
# grow               0.2511      0.613      0.409      0.682      -0.951       1.453
# spy                0.7862      0.755      1.042      0.298      -0.693       2.266
# running            0.0646      0.631      0.102      0.918      -1.171       1.300
# tennessee         -0.0445      0.443     -0.101      0.920      -0.913       0.824
# seat               1.5648      1.205      1.299      0.194      -0.796       3.926
# south              0.8963      0.759      1.180      0.238      -0.592       2.385
# instinct           5.3559      2.845      1.882      0.060      -0.221      10.933
# buckeyes           2.2308      1.019      2.189      0.029       0.234       4.228
# heave              1.3455      1.071      1.256      0.209      -0.754       3.445
# true               1.0979      0.654      1.680      0.093      -0.183       2.379
# discuss            2.7741      1.849      1.500      0.134      -0.850       6.399
# signal             0.7452      0.738      1.010      0.313      -0.701       2.191
# jefferson          2.0300      1.635      1.242      0.214      -1.175       5.235
# nowhere            0.0048      0.482      0.010      0.992      -0.940       0.950
# misfire            1.4726      1.193      1.234      0.217      -0.866       3.811
# stun               4.8080      2.824      1.703      0.089      -0.726      10.342
# espn               0.5060      0.840      0.602      0.547      -1.140       2.152
# redirect           7.1929      6.272      1.147      0.251      -5.099      19.485
# scoring            0.5502      0.680      0.809      0.419      -0.783       1.883
# sammy              2.5963      1.868      1.390      0.165      -1.065       6.258
# denzel             3.5580      2.500      1.423      0.155      -1.342       8.458
# humphrie           8.3672      6.676      1.253      0.210      -4.717      21.451
# rex                0.1824      1.201      0.152      0.879      -2.171       2.535
# player            -0.7260      0.218     -3.328      0.001      -1.153      -0.298
# award              1.9770      1.331      1.485      0.137      -0.632       4.586
# olson              1.2298      1.057      1.164      0.244      -0.841       3.301
# chrome             6.4082      4.314      1.485      0.137      -2.048      14.864
# curly              3.4254      1.829      1.873      0.061      -0.159       7.010
# high              -0.2994      0.408     -0.735      0.462      -1.098       0.499
# quickly            0.0396      0.400      0.099      0.921      -0.745       0.825
# soul               3.0930      1.797      1.722      0.085      -0.428       6.614
# keep              -0.3537      0.271     -1.304      0.192      -0.885       0.178
# bird               1.7248      1.261      1.368      0.171      -0.746       4.196
# value              2.0331      1.494      1.361      0.174      -0.896       4.962
# dr                 2.1568      1.420      1.519      0.129      -0.626       4.940
# carroll            2.6802      1.807      1.484      0.138      -0.861       6.221
# improvise          1.3636      1.255      1.087      0.277      -1.096       3.823
# hunt               1.0999      0.942      1.168      0.243      -0.746       2.946
# healthy            0.1825      0.544      0.335      0.737      -0.884       1.249
# slide             -0.0009      0.477     -0.002      0.999      -0.936       0.934
# direct             0.4290      0.779      0.551      0.582      -1.098       1.956
# red               -0.1204      0.414     -0.291      0.771      -0.931       0.690
# johnny             1.4646      1.265      1.158      0.247      -1.015       3.944
# 49er              -0.0769      0.522     -0.147      0.883      -1.099       0.945
# rather            -3.3973      1.232     -2.757      0.006      -5.812      -0.982
# talk              -3.0287      0.270    -11.235      0.000      -3.557      -2.500
# debut             -3.1408      1.009     -3.113      0.002      -5.118      -1.163
# stress            -9.7111      6.647     -1.461      0.144     -22.739       3.317
# sixth             -3.0758      0.963     -3.195      0.001      -4.963      -1.189
# northwestern      -6.6355      3.407     -1.948      0.051     -13.313       0.042
# bootleg           -2.9143      0.869     -3.352      0.001      -4.618      -1.210
# eat               -3.6469      1.055     -3.458      0.001      -5.714      -1.580
# darren            -6.6418      2.416     -2.749      0.006     -11.378      -1.906
# cyclone           -9.3275      6.803     -1.371      0.170     -22.661       4.006
# product           -6.8463      2.341     -2.925      0.003     -11.434      -2.259
# owen              -5.5434      2.141     -2.590      0.010      -9.739      -1.348
# route             -2.5546      0.432     -5.911      0.000      -3.402      -1.708
# irish             -2.9541      0.971     -3.042      0.002      -4.857      -1.051
# passer            -2.8302      0.796     -3.557      0.000      -4.390      -1.271
# school            -2.1813      0.648     -3.367      0.001      -3.451      -0.912
# velocity          -7.6171      3.461     -2.201      0.028     -14.400      -0.834
# suppose           -2.7355      0.879     -3.112      0.002      -4.459      -1.012
# injury            -2.6848      0.446     -6.023      0.000      -3.558      -1.811
# dalton            -8.3740      7.054     -1.187      0.235     -22.199       5.451
# warm              -3.1927      0.898     -3.556      0.000      -4.952      -1.433
# brian             -2.7055      0.613     -4.416      0.000      -3.906      -1.505
# bowler            -5.0660      2.070     -2.448      0.014      -9.122      -1.010
# clearly           -2.9758      0.731     -4.071      0.000      -4.408      -1.543
# soon              -2.5166      0.509     -4.940      0.000      -3.515      -1.518
# interception      -2.7935      0.303     -9.226      0.000      -3.387      -2.200
# frustrated        -9.9971      7.485     -1.336      0.182     -24.668       4.674
# peyton            -6.9433      3.362     -2.066      0.039     -13.532      -0.355
# oppose            -6.0424      2.754     -2.194      0.028     -11.441      -0.644
# johnson           -2.7833      0.643     -4.331      0.000      -4.043      -1.524
# gunslinger        -4.4674      1.778     -2.512      0.012      -7.953      -0.982
# postseason        -2.9490      0.907     -3.252      0.001      -4.726      -1.172
# bail              -3.5565      1.430     -2.487      0.013      -6.359      -0.754
# chuck             -3.5974      1.322     -2.720      0.007      -6.189      -1.006
# motivate          -9.6716      6.940     -1.394      0.163     -23.274       3.931
# relax             -8.8589      7.011     -1.264      0.206     -22.600       4.883
# pic               -7.8636      3.503     -2.245      0.025     -14.730      -0.997
# delaware         -10.8784      6.463     -1.683      0.092     -23.545       1.788
# aggie             -6.3998      2.665     -2.401      0.016     -11.623      -1.176
# receive           -3.1380      0.674     -4.652      0.000      -4.460      -1.816
# person            -2.7734      0.696     -3.983      0.000      -4.138      -1.409
# history           -2.9974      0.804     -3.729      0.000      -4.573      -1.422
# experience        -2.6681      0.640     -4.166      0.000      -3.923      -1.413
# investigation     -8.8761      7.190     -1.234      0.217     -22.969       5.216
# sign              -3.1735      0.776     -4.090      0.000      -4.694      -1.653
# garçon            -9.5361      7.035     -1.355      0.175     -23.325       4.253
# aggressive        -2.8448      0.831     -3.425      0.001      -4.473      -1.217
# rank              -3.7764      1.128     -3.347      0.001      -5.988      -1.565
# bitch             -4.5496      1.805     -2.521      0.012      -8.086      -1.013
# jim               -2.7955      0.569     -4.914      0.000      -3.910      -1.680
# heady             -5.1874      2.309     -2.247      0.025      -9.712      -0.663
# information       -3.8224      1.480     -2.583      0.010      -6.723      -0.922
# groin             -6.0683      3.125     -1.942      0.052     -12.193       0.056
# update            -5.1317      1.868     -2.747      0.006      -8.793      -1.471
# reid              -5.1175      1.729     -2.959      0.003      -8.507      -1.728
# mcgarrett        -11.5321      6.949     -1.660      0.097     -25.151       2.087
# wear              -3.2321      0.903     -3.577      0.000      -5.003      -1.461
# key               -2.6390      0.565     -4.669      0.000      -3.747      -1.531
# page              -3.1072      0.821     -3.784      0.000      -4.717      -1.498
# roger             -3.0891      0.912     -3.389      0.001      -4.876      -1.303
# exciting          -3.9068      1.801     -2.170      0.030      -7.436      -0.378
# pot               -4.7909      1.828     -2.621      0.009      -8.373      -1.209
# door              -3.6311      1.250     -2.904      0.004      -6.082      -1.181
# bar               -4.7645      1.457     -3.269      0.001      -7.621      -1.908
# travis            -5.6829      2.136     -2.660      0.008      -9.870      -1.496
# semaj             -9.7481      6.860     -1.421      0.155     -23.194       3.698
# circle           -10.2899      6.992     -1.472      0.141     -23.995       3.415
# sneak             -3.4143      0.952     -3.587      0.000      -5.280      -1.548
# cleveland         -3.1895      0.586     -5.442      0.000      -4.338      -2.041
# suffer            -3.9060      1.220     -3.201      0.001      -6.297      -1.515
# tear              -3.6457      1.245     -2.927      0.003      -6.087      -1.205
# jaguar            -3.2200      0.939     -3.429      0.001      -5.061      -1.380
# dalla             -3.7161      1.271     -2.923      0.003      -6.208      -1.224
# jacksonville      -2.9007      0.656     -4.422      0.000      -4.186      -1.615
# york              -3.9451      0.947     -4.164      0.000      -5.802      -2.088
# wolverine        -10.1581      6.694     -1.517      0.129     -23.279       2.963
# studio            -7.2394      2.560     -2.828      0.005     -12.257      -2.222
# huddle            -3.1664      0.740     -4.281      0.000      -4.616      -1.717
# driscoll          -8.7982      6.345     -1.387      0.166     -21.234       3.638
# harbaugh          -3.6675      1.219     -3.008      0.003      -6.057      -1.278
# leslie           -11.1149      6.831     -1.627      0.104     -24.503       2.273
# dallas            -3.4704      0.646     -5.375      0.000      -4.736      -2.205
# inch              -3.7590      1.436     -2.618      0.009      -6.574      -0.944
# pitt              -5.6577      1.982     -2.854      0.004      -9.543      -1.772
# offside           -3.8488      1.345     -2.862      0.004      -6.484      -1.213
# dd               -10.0934      7.000     -1.442      0.149     -23.813       3.626
# alex              -4.6406      1.406     -3.301      0.001      -7.396      -1.886
# center            -3.2828      0.547     -5.997      0.000      -4.356      -2.210
# trojan           -11.9154      6.700     -1.778      0.075     -25.047       1.216
# crossing          -4.5977      1.820     -2.527      0.012      -8.164      -1.031
# backup            -3.4063      0.525     -6.491      0.000      -4.435      -2.378
# connor            -5.7535      2.109     -2.728      0.006      -9.887      -1.620
# hawaii            -5.8149      2.048     -2.840      0.005      -9.828      -1.801
# skip              -9.5123      6.990     -1.361      0.174     -23.212       4.188
# mcveigh           -6.0315      2.144     -2.814      0.005     -10.233      -1.830
# respect           -4.0224      1.115     -3.609      0.000      -6.207      -1.838
# redskin           -3.2240      0.619     -5.211      0.000      -4.437      -2.011
# qb                -5.4494      1.972     -2.763      0.006      -9.315      -1.584
# tell              -3.6154      0.376     -9.616      0.000      -4.352      -2.878
# peterson          -5.8781      2.868     -2.049      0.040     -11.499      -0.257
# weis              -6.7883      2.836     -2.394      0.017     -12.347      -1.230
# tress             -3.6070      1.521     -2.371      0.018      -6.588      -0.625
# detroit           -3.4835      0.860     -4.052      0.000      -5.168      -1.799
# juggle            -7.1383      2.911     -2.452      0.014     -12.844      -1.432
# quick             -3.7862      0.441     -8.578      0.000      -4.651      -2.921
# bottle            -7.2593      2.834     -2.561      0.010     -12.814      -1.704
# reaction          -7.9558      3.192     -2.493      0.013     -14.212      -1.700
# rookie            -3.7179      0.440     -8.445      0.000      -4.581      -2.855
# shepherd         -10.9247      7.196     -1.518      0.129     -25.028       3.179
# fancy             -9.1570      4.333     -2.113      0.035     -17.650      -0.664
# baylor            -5.2399      1.827     -2.867      0.004      -8.821      -1.658
# travesty          -7.8284      3.290     -2.379      0.017     -14.277      -1.380
# offseason         -4.7209      1.208     -3.907      0.000      -7.089      -2.352
# mix               -3.6142      0.787     -4.592      0.000      -5.157      -2.072
# arkansa           -6.7726      2.651     -2.555      0.011     -11.968      -1.577
# golf              -5.0552      1.574     -3.212      0.001      -8.140      -1.971
# steve             -3.8770      0.767     -5.058      0.000      -5.379      -2.375
# dick              -4.2498      0.911     -4.663      0.000      -6.036      -2.464
# jet               -3.8543      0.534     -7.220      0.000      -4.901      -2.808
# michigan          -3.2275      0.569     -5.672      0.000      -4.343      -2.112
# jenkin            -7.3827      2.632     -2.805      0.005     -12.542      -2.223
# mcdaniel         -12.1680      6.832     -1.781      0.075     -25.558       1.222
# bill              -4.0317      0.484     -8.327      0.000      -4.981      -3.083
# bradford         -10.6170      6.814     -1.558      0.119     -23.972       2.738
# byu               -4.8874      1.561     -3.131      0.002      -7.947      -1.828
# bruce            -11.0430      6.948     -1.589      0.112     -24.661       2.575
# baltimore         -4.1073      0.635     -6.469      0.000      -5.352      -2.863
# eagle             -4.1793      0.720     -5.807      0.000      -5.590      -2.769
# injure            -4.1075      0.656     -6.262      0.000      -5.393      -2.822
# doug              -4.5252      1.652     -2.740      0.006      -7.763      -1.288
# wyoming          -11.9736      7.186     -1.666      0.096     -26.058       2.111
# trestman         -12.7246      6.431     -1.979      0.048     -25.330      -0.120
# lion              -3.9857      0.731     -5.449      0.000      -5.419      -2.552
# purdue            -6.0096      1.995     -3.012      0.003      -9.921      -2.098
# shanahan          -8.1739      3.198     -2.556      0.011     -14.442      -1.906
# opposite          -4.9003      1.613     -3.037      0.002      -8.062      -1.738
# denver            -4.2893      0.754     -5.690      0.000      -5.767      -2.812
# inactive          -5.2666      1.578     -3.338      0.001      -8.359      -2.175
# stare             -6.8679      2.330     -2.948      0.003     -11.434      -2.301
# washington        -3.9263      0.704     -5.574      0.000      -5.307      -2.546
# falcon            -4.5106      0.713     -6.325      0.000      -5.908      -3.113
# tony              -5.8038      1.531     -3.791      0.000      -8.804      -2.803
# bob               -5.4004      1.134     -4.761      0.000      -7.624      -3.177
# miami             -4.5353      0.740     -6.127      0.000      -5.986      -3.085
# kody             -11.8900      7.475     -1.591      0.112     -26.540       2.761
# gator             -5.1088      1.236     -4.133      0.000      -7.532      -2.686
# packer            -5.0487      0.610     -8.279      0.000      -6.244      -3.853
# kurt              -5.1874      1.296     -4.003      0.000      -7.727      -2.648
# cris             -12.3419      7.228     -1.707      0.088     -26.509       1.826
# kowski            -5.3976      1.563     -3.452      0.001      -8.462      -2.333
# lincoln           -5.5925      1.591     -3.516      0.000      -8.710      -2.475
# gase             -12.7510      7.499     -1.700      0.089     -27.448       1.946
# pittsburgh        -5.2495      0.940     -5.582      0.000      -7.093      -3.406
# payton            -5.7861      1.187     -4.873      0.000      -8.113      -3.459
# mccarron         -11.7984      7.527     -1.567      0.117     -26.552       2.955
# oklahoma          -4.4502      0.472     -9.436      0.000      -5.375      -3.526
# bronco            -5.2139      0.982     -5.310      0.000      -7.138      -3.290
# setback          -12.8918      7.370     -1.749      0.080     -27.338       1.554
# morris            -6.0511      1.561     -3.876      0.000      -9.111      -2.992
# mccarthy          -6.1346      1.713     -3.580      0.000      -9.493      -2.776
# substitution      -7.9284      3.015     -2.629      0.009     -13.838      -2.018
# cincinnati        -5.3925      0.831     -6.490      0.000      -7.021      -3.764
# matt              -5.4588      0.820     -6.661      0.000      -7.065      -3.853
# dolphin           -6.1463      1.032     -5.955      0.000      -8.169      -4.123
# lsu               -6.1229      1.210     -5.060      0.000      -8.495      -3.751
# bengal            -5.7217      0.949     -6.029      0.000      -7.582      -3.862
# brent             -5.8203      1.425     -4.085      0.000      -8.613      -3.028
# kubiak           -13.4644      7.385     -1.823      0.068     -27.939       1.010
# stanford          -6.0557      1.009     -6.000      0.000      -8.034      -4.078
# iowa              -6.3374      1.413     -4.485      0.000      -9.107      -3.568
# usc               -7.7835      1.818     -4.282      0.000     -11.346      -4.221
# rodger            -7.5006      1.315     -5.704      0.000     -10.078      -4.923
# biscay           -15.3348      7.875     -1.947      0.051     -30.769       0.099
# gruden           -13.2528      4.384     -3.023      0.003     -21.846      -4.659
# simeon           -20.3767      8.590     -2.372      0.018     -37.212      -3.541
# ==================================================================================

# %%
# Save our Model
checkpoint = '__checkpoints'
filename = 'commentary-logit_model'

model.save(os.path.join(checkpoint, filename))

# %%
# Load our Model
checkpoint = '__checkpoints'
filename = 'commentary-logit_model'

model.load(os.path.join(checkpoint, filename))

# %%
# Define function to output plot of the model coefficients

def coefplot(results, figsize=(15, 10), sign=False, title='Coefficients of Features w/ 95% Confidence Intervals'):

    # Create dataframe of results summary 
    coef_df = pd.DataFrame(results.summary().tables[1].data)
    coef_df = coef_df.rename(columns=coef_df.iloc[0]).drop(0, axis=0).reset_index(drop=True)

    # Set index to variable names 
    coef_df = coef_df.set_index(coef_df.columns[0])

    # Change datatype from object to float
    coef_df = coef_df.astype(float)

    # Get errors; (coef - lower bound of conf interval)
    errors = coef_df['coef'] - coef_df['[0.025']
    
    # Append errors column to dataframe
    coef_df['errors'] = errors

    # Sort values by coef ascending
    coef_df = coef_df.sort_values(by=['coef'])
    
    # Only Significat Features
    if sign:
        coef_df = coef_df[coef_df['P>|z|'].astype(float) < 0.05]

    ### Plot Coefficients ###

    # Labels
    variables = list(coef_df.index.values)
    
    # Add variables column to dataframe
    coef_df['variables'] = variables
    
    # Set sns plot style back to 'poster' will make bars wide on plot
    sns.set_context("poster")

    # Define figure, axes, and plot
    fig, ax = plt.subplots(figsize=figsize)
    
    # Error bars for 95% confidence interval
    # Can increase capsize to add whiskers
    coef_df.plot(x='variables', y='coef', 
                 kind='bar', ax=ax, 
                 color='none', fontsize=22, 
                 ecolor='steelblue', capsize=0,
                 yerr='errors', legend=False)
    
    # Set title & labels
    plt.title(title, fontsize=72)
    ax.set_ylabel('Coefficients', fontsize=48)
    ax.set_xlabel('Words', fontsize=48)
    
    # Coefficients
    ax.scatter(x=np.arange(coef_df.shape[0]), 
               marker='o', 
               s=80, 
               y=coef_df['coef'], 
               color='steelblue')
    
    # Line to define zero on the y-axis
    ax.axhline(y=0, linestyle='--', color='red', linewidth=1)
    
    return plt.show()

# %%
coefplot(model, (60, 40), title='Commentary: Coefficients of Features w/ 95% Confidence Intervals')

# %%
coefplot(model, (60, 40), sign=True, title='Commentary: Coefficients of Significant Features w/ 95% Confidence Intervals')

# %%
coef_df = pd.DataFrame(model.summary().tables[1].data)
coef_df = coef_df.rename(columns=coef_df.iloc[0]).drop(0, axis=0).reset_index(drop=True)
coef_df
# Out:
#                        coef    std err          z   P>|z|     [0.025  \
# 0    louisville     11.0198      1.345      8.191   0.000      8.383
# 1         verne     18.8164      7.591      2.479   0.013      3.939
# 2          josh      7.7740      0.739     10.515   0.000      6.325
# 3        gerard     11.2350      3.342      3.362   0.001      4.685
# 4      syracuse     11.9154      3.889      3.064   0.002      4.294
# ..          ...         ...        ...        ...     ...        ...
# 435         usc     -7.7835      1.818     -4.282   0.000    -11.346
# 436      rodger     -7.5006      1.315     -5.704   0.000    -10.078
# 437      biscay    -15.3348      7.875     -1.947   0.051    -30.769
# 438      gruden    -13.2528      4.384     -3.023   0.003    -21.846
# 439      simeon    -20.3767      8.590     -2.372   0.018    -37.212
#
#         0.975]
# 0       13.657
# 1       33.694
# 2        9.223
# 3       17.785
# 4       19.537
# ..         ...
# 435     -4.221
# 436     -4.923
# 437      0.099
# 438     -4.659
# 439     -3.541
#
# [440 rows x 7 columns]

# %%
coef_df['coef'] = coef_df['coef'].astype(float) 
coef_df[coef_df['P>|z|'].astype(float) < 0.05].sort_values('coef', ascending=False)
# Out:
#                      coef    std err          z   P>|z|     [0.025     0.975]
# 1          verne  18.8164      7.591      2.479   0.013      3.939     33.694
# 10      charissa  16.9314      6.209      2.727   0.006      4.762     29.101
# 4       syracuse  11.9154      3.889      3.064   0.002      4.294     19.537
# 52   mountaineer  11.7376      5.808      2.021   0.043      0.353     23.122
# 3         gerard  11.2350      3.342      3.362   0.001      4.685     17.785
# ..           ...      ...        ...        ...     ...        ...        ...
# 399     shanahan  -8.1739      3.198     -2.556   0.011    -14.442     -1.906
# 374        fancy  -9.1570      4.333     -2.113   0.035    -17.650     -0.664
# 396     trestman -12.7246      6.431     -1.979   0.048    -25.330     -0.120
# 438       gruden -13.2528      4.384     -3.023   0.003    -21.846     -4.659
# 439       simeon -20.3767      8.590     -2.372   0.018    -37.212     -3.541
#
# [232 rows x 7 columns]
